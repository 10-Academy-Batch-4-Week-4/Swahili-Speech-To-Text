# %% [markdown]
# <a href="https://colab.research.google.com/github/bezawitalemyimer/Swahili-Speech-To-Text/blob/main/standazed_sampling_Rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('../content/drive')
# Out:
# Drive already mounted at ../content/drive; to attempt to forcibly remount, call drive.mount("../content/drive", force_remount=True).

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.19.5)

# %%
import json
import os
import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt
# %matplotlib inline
import librosa
import librosa.display
import IPython.display as  ipd
import torch
from scipy.io import wavfile as wav
#import torchaudio
#from torchaudio import transforms
import warnings

# %%
#os.chdir("/content/drive/MyDrive/Week-4/speech_data/ALFFA_PUBLIC/ASR/SWAHILI/data/train")

#DATASET_PATH = "wav"
#SAMPLE_RATE = 22050. # 1 sec. of audio a defualt librosa sample_rate
#labels=[]

# %%
file="wav/SWH-15-20110310/SWH-15-20110310_16k-emission_swahili_15h00_-_16h00_tu_20110310_part456.wav"

plt.figure(figsize=(12,6))
data,sample_rate=librosa.load(file)
librosa.display.waveplot(data,sr=sample_rate)
plt.xlabel('Time')
plt.ylabel('Amplitude')
ipd.Audio(file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file  =('wav/SWH-05-20101106/SWH-05-20101106_16k-emission_swahili_05h30_-_06h00_tu_20101106_part10.wav')
librosa_load, librosa_sampling_rate = librosa.load(fullpath)
scipy_sampling_rate, scipy_load = wav.read(fullpath)
print('original sample rate:',scipy_sampling_rate)
print('converted sample rate:',librosa_sampling_rate)
print('\n')
print('original wav file min~max range:',np.min(scipy_load),'~',np.max(scipy_load))
print('converted wav file min~max range:',np.min(librosa_load),'~',np.max(librosa_load))
# Out:
# original sample rate: 16000
# converted sample rate: 22050
#
#
# original wav file min~max range: -24885 ~ 24360
# converted wav file min~max range: -0.7445024 ~ 0.7389587

# %%
plt.figure(figsize=(12, 4))
plt.plot(scipy_load)

# %%
plt.figure(figsize=(12, 4))
plt.plot(librosa_load)
